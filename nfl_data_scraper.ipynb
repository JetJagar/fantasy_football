# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup, Comment

# %%
def scrape_fantasy_season(year):
    url = f'https://www.pro-football-reference.com/years/{year}/fantasy.htm'
    print(f"🔄 Scraping {year}...")
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Try direct table
    table = soup.find('table', id='fantasy')

    # Try inside comments if not found
    if table is None:
        comments = soup.find_all(string=lambda text: isinstance(text, Comment))
        for comment in comments:
            if 'id="fantasy"' in comment:
                table = BeautifulSoup(comment, 'html.parser').find('table', id='fantasy')
                break

    if table is None:
        print(f"❌ {year} failed: No fantasy table found.")
        return None

    df = pd.read_html(str(table))[0]
    df['Season'] = year
    return df

# Loop through 2017–2024
all_years = []
for yr in range(2017, 2025):
    try:
        df = scrape_fantasy_season(yr)
        if df is not None:
            all_years.append(df)
    except Exception as e:
        print(f"⚠️ Error in {yr}: {e}")

# Combine all years
if all_years:
    fantasy_df = pd.concat(all_years, ignore_index=True)
    print(f"✅ Combined DataFrame shape: {fantasy_df.shape}")
    # fantasy_df.to_csv("fantasy_2017_2024.csv", index=False)
    display(fantasy_df.head())
else:
    print("❌ No data was scraped.")
# Out:
# 🔄 Scraping 2017...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2018...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2019...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2020...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2021...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2022...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2023...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 🔄 Scraping 2024...
# C:\Users\Carl\AppData\Local\Temp\ipykernel_9688\1311803391.py:26: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# ✅ Combined DataFrame shape: (5264, 34)
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1      Todd Gurley*+                LAR                 RB
# 1                  2     Le'Veon Bell*+                PIT                 RB
# 2                  3       Kareem Hunt*                KAN                 RB
# 3                  4      Alvin Kamara*                NOR                 RB
# 4                  5      Melvin Gordon                LAC                 RB
#
#   Unnamed: 4_level_0 Games     Passing          ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp Att Yds  ...     2PM  2PP  FantPt
# 0                 23    15  15       0   0   0  ...     NaN  NaN     319
# 1                 25    15  15       0   0   0  ...     NaN  NaN     257
# 2                 22    16  16       0   0   0  ...     NaN  NaN     242
# 3                 22    16   3       0   0   0  ...       1  NaN     239
# 4                 24    16  16       0   0   0  ...     NaN  NaN     230
#
#                                            Season
#      PPR   DKPt   FDPt  VBD PosRank OvRank
# 0  383.3  391.3  351.3  192       1      1   2017
# 1  341.6  349.6  299.1  130       2      2   2017
# 2  295.2  302.2  268.7  115       3      3   2017
# 3  320.4  327.4  279.9  112       4      4   2017
# 4  288.1  294.1  259.1  103       5      5   2017
#
# [5 rows x 34 columns]

# %%
df = pd.read_csv('fantasy_2017_2024.csv', header=[0, 1])
print(df.head())
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player                 Tm            FantPos
# 0                  1      Todd Gurley*+                LAR                 RB
# 1                  2     Le'Veon Bell*+                PIT                 RB
# 2                  3       Kareem Hunt*                KAN                 RB
# 3                  4      Alvin Kamara*                NOR                 RB
# 4                  5      Melvin Gordon                LAC                 RB
#
#   Unnamed: 4_level_0 Games     Passing          ... Scoring      Fantasy  \
#                  Age     G  GS     Cmp Att Yds  ...     2PM  2PP  FantPt
# 0                 23    15  15       0   0   0  ...     NaN  NaN     319
# 1                 25    15  15       0   0   0  ...     NaN  NaN     257
# 2                 22    16  16       0   0   0  ...     NaN  NaN     242
# 3                 22    16   3       0   0   0  ...       1  NaN     239
# 4                 24    16  16       0   0   0  ...     NaN  NaN     230
#
#                                                         Season
#      PPR   DKPt   FDPt  VBD PosRank OvRank Unnamed: 33_level_1
# 0  383.3  391.3  351.3  192       1      1                2017
# 1  341.6  349.6  299.1  130       2      2                2017
# 2  295.2  302.2  268.7  115       3      3                2017
# 3  320.4  327.4  279.9  112       4      4                2017
# 4  288.1  294.1  259.1  103       5      5                2017
#
# [5 rows x 34 columns]

# %%
# flattening the multi-level columns into single strings
df.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df.columns]

# renaming the columns 
df = df.rename(columns={
    'Unnamed: 0_level_0 Rk': 'Rk',
    'Unnamed: 1_level_0 Player': 'Player',
    'Unnamed: 2_level_0 Tm': 'Team',
    'Unnamed: 3_level_0 FantPos': 'Position',
    'Unnamed: 4_level_0 Age': 'Age',
    'Games G': 'Games',
    'Fantasy FantPt': 'FantPt',
    'Fumbles Fmb': 'Fumbles',
    'Fantasy PosRank': 'Pos_Rank',
    'Fantasy OvRank': 'Ovr_Rank'
})

# %%
# cleaning the data to turn 'Nan' values to '0'
df = df.fillna(0)

# removing the index column and re-saving the csv file
df.to_csv('cleaned_fantasy_data.csv', index=False)

df.head()
# Out:
#   Rk          Player Team Position Age Games Games GS Passing Cmp Passing Att  \
# 0  1   Todd Gurley*+  LAR       RB  23    15       15           0           0
# 1  2  Le'Veon Bell*+  PIT       RB  25    15       15           0           0
# 2  3    Kareem Hunt*  KAN       RB  22    16       16           0           0
# 3  4   Alvin Kamara*  NOR       RB  22    16        3           0           0
# 4  5   Melvin Gordon  LAC       RB  24    16       16           0           0
#
#   Passing Yds  ... Scoring 2PM Scoring 2PP FantPt Fantasy PPR Fantasy DKPt  \
# 0           0  ...           0           0    319       383.3        391.3
# 1           0  ...           0           0    257       341.6        349.6
# 2           0  ...           0           0    242       295.2        302.2
# 3           0  ...           1           0    239       320.4        327.4
# 4           0  ...           0           0    230       288.1        294.1
#
#   Fantasy FDPt Fantasy VBD Pos_Rank Ovr_Rank Season Unnamed: 33_level_1
# 0        351.3         192        1        1                       2017
# 1        299.1         130        2        2                       2017
# 2        268.7         115        3        3                       2017
# 3        279.9         112        4        4                       2017
# 4        259.1         103        5        5                       2017
#
# [5 rows x 34 columns]

# %%
# ----------------------------------------------------------------------------------------------------------
# now I will be ranking the top 25 players and defenses

# %%
# gropu the data into seasons
top_players_per_season = {}

# poistions to include
positions = ['QB', 'RB', 'WR', 'TE', 'DEF']

# for each season
for season in sorted(df['Season'].unique()):
    print(f"processing season: {season}")

    season_df = df[df['Season'] == season]

    # top 25 players
    top_players = {}

    for pos in positions:
        pos_df = season_df[season_df['Position'] == pos]
        top_25 = pos_df.sort_values(by='FantPt', ascending=False).head(25)
        top_players[pos] = top_25[['Player', 'Team', 'FantPt', 'Games']]

    top_players_per_season[season] = top_players
# Out:
# processing season: nan
# processing season: 2017.0
# processing season: 2018.0
# processing season: 2019.0
# processing season: 2020.0
# processing season: 2021.0
# processing season: 2022.0
# processing season: 2023.0
# processing season: 2024.0

# %%
# looping through all the seasons top pleyers and defenses
for season, pos_data in top_players_per_season.items():
    print(f"==={season}===")
    for pos, df in pos_data.items():
        print(f"\nTop 25 {pos}:")
        print(df.to_string(index=False))
# Out:
# ===nan===
#
# Top 25 QB:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
#
# Top 25 RB:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
#
# Top 25 WR:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
#
# Top 25 TE:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2017.0===
#
# Top 25 QB:
#           Player Team FantPt Games
#     Landry Jones  PIT      9     3
#    C.J. Beathard  SFO     89     7
#  Jimmy Garoppolo  SFO     87     6
#     Nate Sudfeld  PHI      8     1
# Ryan Fitzpatrick  TAM     74     6
#   Brock Osweiler  DEN     68     6
#      Brian Hoyer  2TM     64    11
#   Blaine Gabbert  ARI     62     5
#       Tom Savage  HOU     51     8
#     Drew Stanton  ARI     50     5
#         Joe Webb  BUF      5    16
#     Sean Mannion  LAR      5     5
#       Matt Moore  MIA     41     4
#    Tanner Gentry  CHI      4     4
#  Russell Wilson*  SEA    348    16
#     Mike Glennon  CHI     34     4
#      Kevin Hogan  CLE     34     4
#       Nick Foles  PHI     34     7
#       T.J. Yates  HOU     34     4
#    A.J. McCarron  CIN      3     3
#     Cody Kessler  CLE      3     3
#       Cam Newton  CAR    299    16
#      Tom Brady*+  NWE    296    16
#      Alex Smith*  KAN    295    15
#    Carson Wentz*  PHI    282    13
#
# Top 25 RB:
#          Player Team FantPt Games
#  Ameer Abdullah  DET     99    14
#     Tarik Cohen  CHI     97    16
#     Zach Zenner  DET      9     8
#   Samaje Perine  WAS     87    16
#      Matt Forte  NYJ     83    12
#     Matt Breida  SFO     83    16
#     Marlon Mack  IND     82    14
#   Corey Clement  PHI     82    16
#   Austin Ekeler  LAC     80    16
#    Bobby Rainey  BAL      8     4
#     James White  NWE     78    14
#       Rod Smith  DAL     73    15
#   Wayne Gallman  NYG     71    13
#     Aaron Jones  GNB     71    12
#   Peyton Barber  TAM     70    16
#  Brandon Bolden  NWE      7    16
#      Brian Hill  2TM      7     7
#   David Johnson  ARI      7     1
#      Tre Madden  SEA      7     8
#  Byron Marshall  WAS      7     4
#   Ty Montgomery  GNB     69     8
# Adrian Peterson  2TM     68    10
#  Mike Gillislee  NWE     68     9
#     Doug Martin  TAM     67    11
#   Alfred Morris  DAL     65    14
#
# Top 25 WR:
#           Player Team FantPt Games
#     Mike Wallace  BAL     99    15
#  Travis Benjamin  LAC     96    16
#  Tyrell Williams  LAC     95    16
#  Jamison Crowder  WAS     94    15
#     Randall Cobb  GNB     93    15
#      Marqise Lee  JAX     92    14
#      Keelan Cole  JAX     91    16
#      Mike Thomas  LAR      9     8
#      Bobo Wilson  TAM      9     3
#      Chad Hansen  NYJ      9    15
#     Ryan Switzer  DAL      9    16
#   DeSean Jackson  TAM     89    14
#  Kelvin Benjamin  2TM     87    14
# Sterling Shepard  NYG     86    11
#     Josh Doctson  WAS     85    16
#      Will Fuller  HOU     85    10
#     Jordy Nelson  GNB     84    15
#  Martavis Bryant  PIT     83    15
#       Ryan Grant  WAS     81    16
#     Trevor Davis  GNB      8    16
#    Michael Floyd  MIN      8    11
#    Justin Hunter  PIT      8     7
# Breshad Perriman  BAL      8    11
#      Brian Quick  WAS      8    11
#    Neal Sterling  NYJ      8    11
#
# Top 25 TE:
#          Player Team FantPt Games
#   Cameron Brate  TAM     95    16
#  Xavier Grimble  PIT      9    15
#    Jerell Adams  NYG      9    16
#    Luke Stocker  2TM      9    12
#     Jack Doyle*  IND     89    15
#   Jason Witten*  DAL     84    16
#     Tyler Kroft  CIN     82    16
#    Hunter Henry  LAC     82    14
#       Lee Smith  OAK      8    16
#   Clive Walford  OAK      8    13
#      Jared Cook  OAK     79    16
#      Eric Ebron  DET     79    16
#    Vernon Davis  WAS     79    16
#      Ben Watson  BAL     76    16
#     O.J. Howard  TAM     75    14
#   Austin Hooper  ATL     71    16
# Jeremy Sprinkle  WAS      7    11
#   Tanner McEvoy  SEA      7    15
#   Derek Carrier  LAR      7    14
#    Charles Clay  BUF     68    13
#   George Kittle  SFO     64    15
#  Marcedes Lewis  JAX     64    16
#     David Njoku  CLE     63    16
#      Ben Koyack  JAX      6    16
#      Alan Cross  TAM      6     8
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2018.0===
#
# Top 25 QB:
#             Player Team FantPt Games
#       Jeff Driskel  CIN     85     9
#         Nick Foles  PHI     75     5
#      C.J. Beathard  SFO     75     6
#  Teddy Bridgewater  NOR      7     5
#     Derek Anderson  BUF      7     2
#     Brock Osweiler  MIA     68     7
#       Josh Johnson  WAS     50     4
#       Nate Sudfeld  PHI      5     2
#      DeShone Kizer  GNB      5     3
#    Jimmy Garoppolo  SFO     48     3
#  Patrick Mahomes*+  KAN    417    16
#       Tyrod Taylor  CLE     41     4
#       Cody Kessler  JAX     39     5
#     Terrelle Pryor  2TM     37     8
#          Matt Ryan  ATL    354    16
# Ben Roethlisberger  PIT    341    16
#    Deshaun Watson*  HOU    332    16
#     Blaine Gabbert  TEN     33     8
#       Andrew Luck*  IND    327    16
#     Aaron Rodgers*  GNB    313    16
#        Jared Goff*  LAR    310    16
#        Drew Brees*  NOR    304    15
#       Chase Daniel  CHI     30     5
#    Russell Wilson*  SEA    298    16
#      Dak Prescott*  DAL    286    16
#
# Top 25 RB:
#            Player Team FantPt Games
#      Nyheim Hines  IND     98    16
# Leonard Fournette  JAX     98     8
#      Alex Collins  BAL     94    10
#      LeSean McCoy  BUF     93    14
#        Frank Gore  MIA     91    14
# Dontrell Hilliard  CLE      9    11
#    D'Onta Foreman  HOU      9     1
#   Devonta Freeman  ATL      9     2
#     Jalen Richard  OAK     89    16
# Wendell Smallwood  PHI     89    16
#       Gus Edwards  BAL     88    11
#       Carlos Hyde  2TM     88    14
#   Jamaal Williams  GNB     87    16
#     Royce Freeman  DEN     87    14
#      Duke Johnson  CLE     85    16
#       Mark Walton  CIN      8    14
#     Elijhaa Penny  NYG      8    14
# LeGarrette Blount  DET     77    16
#       Alfred Blue  HOU     77    16
#   Damien Williams  KAN     76    16
#        Josh Adams  PHI     75    14
#         Ito Smith  ATL     71    14
#     Kenjon Barner  2TM      7     9
#    Detrez Newsome  LAC      7     9
#    Elijah McGuire  NYJ     67     8
#
# Top 25 WR:
#                Player Team FantPt Games
#           Josh Gordon  2TM     98    12
#         Curtis Samuel  CAR     98    13
#      Demaryius Thomas  2TM     98    15
#        Allen Robinson  CHI     98    13
#          Kenny Stills  MIA     97    15
#       Tyrell Williams  LAC     97    16
#           Cooper Kupp  LAR     95     8
#          Jordy Nelson  OAK     94    15
#      Courtland Sutton  DEN     94    16
#          Doug Baldwin  SEA     92    13
#           Kevin White  CHI      9     9
#      Antonio Callaway  CLE     89    16
#        Anthony Miller  CHI     87    15
#          Cole Beasley  DAL     85    16
#        Taylor Gabriel  CHI     85    16
#        Donte Moncrief  JAX     83    16
#        Christian Kirk  ARI     81    12
#          Marvin Jones  DET     81     9
#        Cameron Batson  TEN      8    11
#         Corey Coleman  NYG      8     8
#       Rashard Higgins  CLE     79    13
#        Devin Funchess  CAR     79    14
#      Michael Crabtree  BAL     79    16
#          Dante Pettis  SFO     77    12
# Cordarrelle Patterson  NWE     76    15
#
# Top 25 TE:
#           Player Team FantPt Games
#      Trey Burton  CHI     93    16
#   Austin Hooper*  ATL     92    16
#     Luke Willson  DET      9    14
#        Jake Butt  DEN      9     3
#      David Njoku  CLE     88    16
#     Kyle Rudolph  MIN     87    16
#      O.J. Howard  TAM     87    10
#   Rob Gronkowski  NWE     84    13
#   Vance McDonald  PIT     83    15
#      Evan Engram  NYG     81    11
#      Matt Lengel  CIN      8    11
#     Logan Thomas  BUF      8    12
#    Tyler Conklin  MIN      8    16
#     Jimmy Graham  GNB     76    16
#    Chris Herndon  NYJ     74    16
#     Mark Andrews  BAL     73    16
#   Xavier Grimble  PIT      7    16
#   Joshua Perkins  PHI      7     9
#   Eric Tomlinson  NYJ      7    15
# Jermaine Gresham  ARI      7    13
#       Blake Bell  JAX      7    10
#      Jordan Reed  WAS     66    13
#    Cameron Brate  TAM     63    16
#      C.J. Uzomah  CIN     62    16
#   David Grinnage  JAX      6     4
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2019.0===
#
# Top 25 QB:
#            Player Team FantPt Games
# Teddy Bridgewater  NOR     90     9
#         Luke Falk  NYJ      9     3
#        Joe Flacco  DEN     85     8
#    Marcus Mariota  TEN     85     7
#    Dwayne Haskins  WAS     77     9
#         Drew Lock  DEN     68     5
#      Tyrod Taylor  LAC      6     8
#     Brett Hundley  ARI      6     3
#      Matt Barkley  BUF      6     2
#      Jeff Driskel  DET     57     3
#       Eli Manning  NYG     54     4
#      David Blough  DET     54     5
#     Devlin Hodges  PIT     51     8
#        Matt Moore  KAN     42     6
#   Lamar Jackson*+  BAL    416    15
#        Colt McCoy  WAS      4     1
#      Mike Glennon  OAK      4     2
#        Nick Foles  JAX     38     4
#      Dak Prescott  DAL    338    16
#       Matt Schaub  ATL     33     6
#     Brandon Allen  DEN     33     3
#   Russell Wilson*  SEA    329    16
#   Deshaun Watson*  HOU    320    15
#    Jameis Winston  TAM    305    16
#        Josh Allen  BUF    289    16
#
# Top 25 RB:
#             Player Team FantPt Games
#      Royce Freeman  DEN     99    16
#       LeSean McCoy  KAN     91    13
#     Marshawn Lynch  SEA      9     1
#      Kenjon Barner  ATL      9    14
#   D'Ernest Johnson  CLE      9    16
# DeAndre Washington  OAK     86    16
#        Gus Edwards  BAL     86    16
#        Tarik Cohen  CHI     85    16
#        Matt Breida  SFO     84    13
#         Frank Gore  BUF     82    16
#    Kerryon Johnson  DET     75     8
#       Rex Burkhead  NWE     74    13
#       Tony Pollard  DAL     74    15
#       Nyheim Hines  IND     74    16
#       Boston Scott  PHI     73    11
#      Chase Edmonds  ARI     71    13
#    Devontae Booker  DEN      7    16
#     Troymaine Pope  LAC      7    14
#       Spencer Ware  KAN      7     3
#  Dwayne Washington  NOR      7    16
#         Tra Carson  2TM      7     3
#      Rashaad Penny  SEA     67    10
#        Kareem Hunt  CLE     64     8
#          Zach Line  NOR      6    12
#     Brandon Wilson  CIN      6    12
#
# Top 25 WR:
#           Player Team FantPt Games
#      Zach Pascal  IND     94    16
#  Mecole Hardman*  KAN     94    16
#   Dede Westbrook  JAX     91    15
# James Washington  PIT     90    15
#    Robert Foster  BUF      9    13
#        Lee Smith  BUF      9    16
# Antonio Callaway  CLE      9     4
#  Christian Blake  ATL      9     9
#    Sammy Watkins  KAN     87    14
#      Will Fuller  HOU     85    11
# Sterling Shepard  NYG     85    10
#   Hunter Renfrow  OAK     85    13
#     Adam Thielen  MIN     84    10
#     Kenny Stills  HOU     80    13
#      T.Y. Hilton  IND     80    10
#  Trent Sherfield  ARI      8    16
#   KhaDarel Hodge  CLE      8    16
#   Ventell Bryant  DAL      8    12
#    Damion Willis  CIN      8    10
#   Alshon Jeffery  PHI     79    10
#   Danny Amendola  DET     79    15
#      Steven Sims  WAS     76    16
#    Brandin Cooks  LAR     76    14
#   Anthony Miller  CHI     76    16
#  Phillip Dorsett  NWE     72    14
#
# Top 25 TE:
#         Player Team FantPt Games
#   Hunter Henry  LAC     95    12
#   Tyler Higbee  LAR     91    15
#     J.P. Holtz  2TM      9    15
#    Mo Alie-Cox  IND      9    16
# Dallas Goedert  PHI     87    15
#   Mike Gesicki  MIA     85    16
#    Taysom Hill  NOR     83    16
#   Luke Willson  SEA      8     8
#    Trey Burton  CHI      8     8
#   Jason Witten  DAL     77    16
#   Darren Fells  HOU     76    16
#   Kyle Rudolph  MIN     75    16
#     Greg Olsen  CAR     72    14
#      Noah Fant  DEN     71    16
#    Jonnu Smith  TEN     70    16
#  Durham Smythe  MIA      7    16
#  Cethan Carter  CIN      7    15
#     Blake Bell  KAN      7    15
#    Geoff Swaim  JAX      7     6
#    Jack Doyle*  IND     69    16
#    Evan Engram  NYG     65     8
#   Tyler Eifert  CIN     64    16
#   Ryan Griffin  NYJ     64    13
#   Jimmy Graham  GNB     63    16
#  Clive Walford  MIA      6     7
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2020.0===
#
# Top 25 QB:
#           Player Team FantPt Games
#      P.J. Walker  CAR      9     4
#     Tyrod Taylor  LAC      9     2
#   Trace McSorley  BAL      9     2
#     Matt Barkley  BUF      9     5
#  Chris Streveler  ARI      8     5
#       Alex Smith  WAS     72     8
#      Ben DiNucci  DAL      7     3
#   Dwayne Haskins  WAS     68     7
#  Jimmy Garoppolo  SFO     64     6
#     Mike Glennon  JAX     61     5
#       Joe Flacco  NYJ     55     5
#    C.J. Beathard  SFO     52     6
#    Brandon Allen  CIN     50     5
#       Kyle Allen  WAS     45     4
#      Josh Allen*  BUF    395    16
#  Aaron Rodgers*+  GNB    382    16
#    Kyler Murray*  ARI    379    16
# Patrick Mahomes*  KAN    374    15
#  Deshaun Watson*  HOU    369    16
#  Russell Wilson*  SEA    360    16
#   Ryan Tannehill  TEN    343    16
#        Tom Brady  TAM    338    16
#    Lamar Jackson  BAL    333    15
#   Justin Herbert  LAC    333    15
#     Kirk Cousins  MIN    306    16
#
# Top 25 RB:
#              Player Team FantPt Games
#     Jamaal Williams  GNB     96    14
#   Leonard Fournette  TAM     96    13
#        Tony Pollard  DAL     93    16
#     Jerick McKinnon  SFO     93    16
#           Cam Akers  LAR     91    13
#      Artavis Pierce  CHI      9     5
#      Saquon Barkley  NYG      9     2
#       Tevin Coleman  SFO      9     8
#           Zack Moss  BUF     88    13
#       Malcolm Brown  LAR     86    16
#       Damien Harris  NWE     86    10
#          Frank Gore  NYJ     84    15
#      Raheem Mostert  SFO     84     8
#        Rex Burkhead  NWE     83    10
#        Justice Hill  BAL      8    12
#        C.J. Prosise  HOU      8    10
#           Joe Mixon  CIN     79     6
#  Alexander Mattison  MIN     74    13
# Christian McCaffrey  CAR     73     3
#        Boston Scott  PHI     71    16
#          Brian Hill  ATL     70    16
#        Buddy Howell  HOU      7    14
#      Jaylen Samuels  PIT      7    14
#     Anthony Sherman  KAN      7    13
#       Jonathan Ward  ARI      7    14
#
# Top 25 WR:
#               Player Team FantPt Games
# Laviska Shenault Jr.  JAX     99    14
#       Christian Kirk  ARI     98    14
#     Sterling Shepard  NYG     97    12
#          Julio Jones  ATL     95     9
#          Zach Pascal  IND     93    16
#       Darnell Mooney  CHI     91    16
#       Darius Slayton  NYG     91    16
#        Justin Watson  TAM      9    11
#      Parris Campbell  IND      9     2
#          Austin Carr  NOR      9     6
#          Austin Mack  NYG      9    11
#             Joe Reed  LAC      9    11
#         Trent Taylor  SFO      9    12
#       Mecole Hardman  KAN     87    16
#      Rashard Higgins  CLE     84    13
#        Jakobi Meyers  NWE     84    14
#          David Moore  SEA     84    16
#      Kendrick Bourne  SFO     81    15
#            Greg Ward  PHI     80    16
#         Jake Kumerow  BUF      8     6
#       Travis Fulgham  PHI     78    13
#       Hunter Renfrow  LVR     76    16
#        Antonio Brown  TAM     72     8
#        Josh Reynolds  LAR     72    16
#      Isaiah McKenzie  BUF     70    16
#
# Top 25 TE:
#           Player Team FantPt Games
#      Jonnu Smith  TEN     99    15
#     Jimmy Graham  CHI     94    16
#     Hayden Hurst  ATL     93    16
#       Jared Cook  NOR     90    15
#     Ryan Griffin  NYJ      9    15
# Dominique Dafney  GNB      9     5
#        Noah Fant  DEN     87    15
#       Eric Ebron  PIT     86    15
#     Hunter Henry  LAC     85    14
#   Dalton Schultz  DAL     84    16
#     Tyler Higbee  LAR     84    15
#     Evan Engram*  NYG     78    16
#    George Kittle  SFO     77     8
#   Dallas Goedert  PHI     70    11
#   Colin Thompson  CAR      7    15
#    Irv Smith Jr.  MIN     69    13
#    Austin Hooper  CLE     68    13
#       Dan Arnold  ARI     66    16
#      Jason Croom  PHI      6     4
#     Luke Stocker  ATL      6    16
#    Jordan Thomas  2TM      6     6
#     Darren Fells  HOU     55    16
#      Trey Burton  IND     55    13
#   Gerald Everett  LAR     52    16
# Demetrius Harris  CHI      5    15
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2021.0===
#
# Top 25 QB:
#             Player Team FantPt Games
#     Trevor Siemian  NOR     90     6
#         Cam Newton  CAR     86     8
#        Andy Dalton  CHI     84     8
#      Tyler Huntley  BAL     83     7
#       Tyrod Taylor  HOU     82     6
#  Mitchell Trubisky  BUF      8     6
#    Garrett Gilbert  WAS      8     1
#         Kyle Allen  WAS      8     2
#    Jacoby Brissett  MIA     72    11
#         Trey Lance  SFO     65     6
#         Geno Smith  SEA     54     4
#          Drew Lock  DEN     51     6
#       Josh Johnson  2TM     46     4
#         Mike White  NYJ     44     4
#         Colt McCoy  ARI     41     8
#         Josh Allen  BUF    403    17
#    Justin Herbert*  LAC    381    17
#         Tom Brady*  TAM    375    17
#   Patrick Mahomes*  KAN    362    17
# Gardner Minshew II  PHI     34     4
#    Aaron Rodgers*+  GNB    332    16
#   Matthew Stafford  LAR    330    17
#       Dak Prescott  DAL    321    16
#         Joe Burrow  CIN    314    16
#        Jalen Hurts  PHI    312    15
#
# Top 25 RB:
#                Player Team FantPt Games
# Clyde Edwards-Helaire  KAN     99    10
#            Mike Davis  ATL     94    17
#       Latavius Murray  BAL     94    14
#       Jamaal Williams  DET     94    13
#    Alexander Mattison  MIN     94    16
#   Christian McCaffrey  CAR     91     7
#         Miles Sanders  PHI     91    12
#      Kenneth Gainwell  PHI     90    16
#         Andy Janovich  CLE      9    13
#          Deon Jackson  IND      9     9
#          JaQuan Hardy  DAL      9     3
#           Kareem Hunt  CLE     88     8
#          Boston Scott  PHI     86    16
#         J.D. McKissic  WAS     85    11
#        D'Onta Foreman  TEN     85     9
#      D'Ernest Johnson  CLE     85    17
#            Ty Johnson  NYJ     83    16
#        Brandon Bolden  NWE     83    17
#           Mark Ingram  2TM     82    14
#             Zack Moss  BUF     82    13
#          Rex Burkhead  HOU     79    16
#          Kenyan Drake  LVR     73    12
#          Nyheim Hines  IND     73    17
#         Jonathan Ward  ARI      7    13
#       Ronald Jones II  TAM     69    16
#
# Top 25 WR:
#                Player Team FantPt Games
#          Russell Gage  ATL     97    14
#          Elijah Moore  NYJ     95    11
#      Courtland Sutton  DEN     92    17
#          Robert Woods  LAR     92     9
#         Gabriel Davis  BUF     91    16
#      Emmanuel Sanders  BUF     90    14
#        Anthony Miller  2TM      9     3
#           Josh Gordon  KAN      9    12
#        Cameron Batson  TEN      9     4
#         Robbie Chosen  CAR     86    17
#     Odell Beckham Jr.  2TM     85    14
#         Byron Pringle  KAN     85    17
#         Kalif Raymond  DET     84    16
#        Mecole Hardman  KAN     82    17
#         Jarvis Landry  CLE     81    12
#      Preston Williams  MIA      8     8
#         Dezmon Patmon  IND      8     8
#         Antonio Brown  TAM     79     7
#          Cole Beasley  BUF     77    16
#          Deonte Harty  NOR     77    13
# Donovan Peoples-Jones  CLE     76    14
#      Braxton Berrios+  NYJ     75    16
#         Bryan Edwards  LVR     75    16
#          Quez Watkins  PHI     73    17
#           Corey Davis  NYJ     71     9
#
# Top 25 TE:
#          Player Team FantPt Games
#  Pat Freiermuth  PIT     92    16
#    Mike Gesicki  MIA     92    17
#       Noah Fant  DEN     91    16
#     Sean McKeon  DAL      9     9
#    Tyler Higbee  LAR     86    15
#  T.J. Hockenson  DET     84    12
#      Jared Cook  LAC     84    16
#   Tyree Jackson  PHI      8     9
#     Drew Sample  CIN      8    17
#   Darren Waller  LVR     79    11
#     C.J. Uzomah  CIN     79    16
#   Tyler Conklin  MIN     77    17
#     David Njoku  CLE     72    16
#  Gerald Everett  SEA     70    15
#     Josh Oliver  BAL      7    14
#       Cole Kmet  CHI     61    17
#    Luke Farrell  JAX      6    15
#     Evan Engram  NYG     57    15
#     Mo Alie-Cox  IND     56    17
#   Austin Hooper  CLE     55    16
#   Foster Moreau  LVR     55    17
#      Jack Doyle  IND     50    17
#    Tre' McKitty  LAC      5    11
# Charlie Woerner  SFO      5    17
#   Cameron Brate  TAM     49    17
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2022.0===
#
# Top 25 QB:
#             Player Team FantPt Games
#        Zach Wilson  NYJ     98     9
#    Chris Streveler  NYJ      9     2
#     Trace McSorley  ARI      9     6
#     Deshaun Watson  CLE     86     6
#        Sam Darnold  CAR     86     6
#    Nathan Peterman  CHI      8     3
#       Chase Daniel  LAC      8     4
#  Mitchell Trubisky  PIT     74     7
#      Anthony Brown  BAL      6     2
#         Mike White  NYJ     57     4
#        Cooper Rush  DAL     57     9
#     Tyler Huntley*  BAL     50     6
#     Blaine Gabbert  TAM      5     1
#         Joe Flacco  NYJ     48     5
#     Jameis Winston  NOR     44     3
#    Jarrett Stidham  LVR     43     5
#  Patrick Mahomes*+  KAN    416    17
#        Josh Allen*  BUF    396    16
#     Desmond Ridder  ATL     39     4
#        P.J. Walker  CAR     39     6
#       Bailey Zappe  NWE     39     4
#  Teddy Bridgewater  MIA     38     5
#       Jalen Hurts*  PHI    378    15
# Gardner Minshew II  PHI     37     5
#       Sam Ehlinger  IND     36     4
#
# Top 25 RB:
#                Player Team FantPt Games
#           Breece Hall  NYJ     96     7
#           Kareem Hunt  CLE     92    17
#       Phillip Lindsay  IND      9     3
#        Jordan Wilkins  IND      9     4
#         Rachaad White  TAM     89    17
#          Kenyan Drake  BAL     87    12
#            James Cook  BUF     85    16
#        Michael Carter  NYJ     85    16
# Clyde Edwards-Helaire  KAN     81    10
#       Jaret Patterson  WAS      8     3
#           Tyler Badie  DEN      8     1
#        James Robinson  2TM     78    11
#         Chuba Hubbard  CAR     74    15
#         Damien Harris  NWE     74    11
#          J.K. Dobbins  BAL     74     8
#    Alexander Mattison  MIN     73    17
#           Zamir White  LVR      7    14
#       Ke'Shawn Vaughn  TAM      7    15
#         Jaylen Warren  PIT     65    16
#          Eno Benjamin  3TM     65    15
#      Kenneth Gainwell  PHI     65    17
#         Melvin Gordon  DEN     62    10
#     Trayveon Williams  CIN      6     8
#           Gus Edwards  BAL     59     9
#         Chase Edmonds  2TM     58    13
#
# Top 25 WR:
#                   Player Team FantPt Games
#             Keenan Allen  LAC     98    10
#             Mack Hollins  LVR     97    17
#              Josh Palmer  LAC     97    16
#             Jahan Dotson  WAS     96    12
#              K.J. Osborn  MIN     96    17
#          Diontae Johnson  PIT     95    17
#         Courtland Sutton  DEN     95    15
#                 Cam Sims  WAS      9    17
#            Michael Bandy  LAC      9    10
#            Brandin Cooks  HOU     89    13
#           Marquise Brown  ARI     89    12
#          DeAndre Hopkins  ARI     88     9
#          Parris Campbell  IND     86    17
#           Darius Slayton  NYG     82    16
# Marquez Valdes-Scantling  KAN     80    17
#          Brandon Johnson  DEN      8     7
#          Devin Duvernay*  BAL     79    14
#          Isaiah McKenzie  BUF     78    15
#             Richie James  NYG     76    17
#             Russell Gage  TAM     73    13
#           Rashid Shaheed  NOR     73    12
#           DeVante Parker  NWE     72    13
#               Noah Brown  DAL     72    16
#             Marvin Jones  JAX     71    16
#              Alec Pierce  IND     71    16
#
# Top 25 TE:
#            Player Team FantPt Games
#         Cole Kmet  CHI     97    17
#     Juwan Johnson  NOR     93    16
#     Armani Rogers  WAS      9    11
#      Kyle Rudolph  TAM      9     9
#      Parker Hesse  ATL      9    17
#      Dawson Knox*  BUF     88    15
#    Dalton Schultz  DAL     86    15
#    Dallas Goedert  PHI     86    12
#    Pat Freiermuth  PIT     85    16
#       David Njoku  CLE     84    14
#    Gerald Everett  LAC     82    16
#      Jordan Akins  HOU     80    15
#      Tyler Higbee  LAR     80    17
#  Grant Calcaterra  PHI      8    15
#        Blake Bell  KAN      8     3
#     Tyler Conklin  NYJ     74    17
#         Noah Fant  SEA     73    17
#       Andrew Beck  DEN      7    13
#      Tre' McKitty  LAC      7    17
#       Tyler Mabry  SEA      7     2
#         Zach Ertz  ARI     69    10
#      Mike Gesicki  MIA     66    17
# Chigoziem Okonkwo  TEN     65    17
#      Hunter Henry  NWE     63    17
#      Nick Vannett  2TM      6     9
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2023.0===
#
# Top 25 QB:
#             Player Team FantPt Games
#       Tommy DeVito  NYG     94     9
#       Tyrod Taylor  NYG     87    11
#     Deshaun Watson  CLE     87     6
#     Ryan Tannehill  TEN     80    10
# Anthony Richardson  IND     73     4
#       Clayton Tune  ARI      7     7
#       Bailey Zappe  NWE     69    10
#       Easton Stick  LAC     68     5
#       Nick Mullens  MIN     67     5
#    Taylor Heinicke  ATL     66     5
#    Jimmy Garoppolo  LVR     64     7
#     Blaine Gabbert  KAN      6     2
#       Daniel Jones  NYG     57     6
#       Tyson Bagent  CHI     53     5
#        Brian Hoyer  LVR      5     3
#       Brett Rypien  LAR      5     2
#  Mitchell Trubisky  PIT     49     5
#      Mason Rudolph  PIT     40     4
#         Josh Allen  BUF    393    17
#       Jalen Hurts*  PHI    357    17
#      Dak Prescott*  DAL    343    17
#    Lamar Jackson*+  BAL    331    16
#        Jordan Love  GNB    319    17
#       Malik Willis  TEN      3     3
#        Cooper Rush  DAL      3     7
#
# Top 25 RB:
#            Player Team FantPt Games
#         AJ Dillon  GNB     96    15
#    Khalil Herbert  CHI     93    12
# Israel Abanikanda  NYJ      9     6
#      Justice Hill  BAL     81    16
#    D'Onta Foreman  CHI     80     9
#       Ty Chandler  MIN     80    17
# Trayveon Williams  CIN      8    17
#      Deuce Vaughn  DAL      8     7
#   Dare Ogunbowale  HOU      8    12
#    Antonio Gibson  WAS     79    16
#       Rico Dowdle  DAL     75    16
# Jaleel McLaughlin  DEN     75    17
#   Zach Charbonnet  SEA     73    16
#     Samaje Perine  DEN     71    17
#     Dameon Pierce  HOU     70    14
#   Gary Brightwell  NYG      7     7
#         Eric Gray  NYG      7    13
#   Roschon Johnson  CHI     68    15
#  Kenneth Gainwell  PHI     67    16
#   Latavius Murray  BUF     66    16
#   Keaton Mitchell  BAL     61     8
#     Miles Sanders  CAR     61    16
#   Damien Williams  ARI      6     3
#       Zamir White  LVR     59    17
#   Jerick McKinnon  KAN     59    12
#
# Top 25 WR:
#             Player Team FantPt Games
#        Tee Higgins  CIN     96    12
#      Curtis Samuel  WAS     95    16
#     Christian Kirk  JAX     93    12
#       Richie James  KAN      9     9
#         Josh Downs  IND     89    17
#      Josh Reynolds  DET     89    17
#        Jerry Jeudy  DEN     88    16
# Jaxon Smith-Njigba  SEA     87    17
#     Marquise Brown  ARI     84    14
#   Dontayvion Wicks  GNB     81    15
#           DJ Chark  CAR     81    15
#       Samori Toure  GNB      8    11
#          Tim Jones  JAX      8    17
#         Tyler Boyd  CIN     78    17
#     Michael Wilson  ARI     77    13
#       Jahan Dotson  WAS     76    17
#      Khalil Shakir  BUF     74    17
#  Wan'Dale Robinson  NYG     73    15
#       Elijah Moore  CLE     73    17
#  Odell Beckham Jr.  BAL     73    14
#        Tutu Atwell  LAR     73    16
#   Christian Watson  GNB     73     9
#        K.J. Osborn  MIN     72    16
#       Chris Conley  SFO      7     8
#        Simi Fehoko  LAC      7     6
#
# Top 25 TE:
#             Player Team FantPt Games
#     Dalton Schultz  HOU     92    15
#       Mark Andrews  BAL     90    10
#     Marcedes Lewis  CHI      9    17
#        Geoff Swaim  ARI      9    14
#     Quintin Morris  BUF      9    15
#         Kyle Pitts  ATL     84    17
#           Ben Sims  GNB      8    17
#     Brycen Hopkins  LAR      8    15
#       Hunter Henry  NWE     78    14
#     Dallas Goedert  PHI     77    14
#     Dalton Kincaid  BUF     77    16
#        Jonnu Smith  ATL     74    17
#       Logan Thomas  WAS     72    16
#      Isaiah Likely  BAL     71    17
#         Cade Otton  TAM     70    17
#         Blake Bell  KAN      7    17
#     Josiah Deguara  GNB      7    15
#       Tyler Higbee  LAR     62    15
#      Tyler Conklin  NYJ     62    17
#      Darren Waller  NYG     61    12
#      Juwan Johnson  NOR     61    13
#     Gerald Everett  LAC     60    15
#         Ian Thomas  CAR      6    12
# Darnell Washington  PIT      6    17
#           Ko Kieft  TAM      6    16
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []
# ===2024.0===
#
# Top 25 QB:
#             Player Team FantPt Games
#         Joe Flacco  IND     99     8
#          Mac Jones  JAX     96    10
# Gardner Minshew II  LVR     96    10
#      Mason Rudolph  TEN     96     8
#    Aidan O'Connell  LVR     93     9
#          Drew Lock  NYG     80     8
#    Skylar Thompson  MIA      8     3
#     Deshaun Watson  CLE     77     7
#       Bailey Zappe  CLE      7     1
#    Spencer Rattler  NOR     67     7
#      Tyler Huntley  MIA     61     5
#      Brandon Allen  SFO      6     3
#        Andy Dalton  CAR     59     6
#       Malik Willis  GNB     52     7
#       Carson Wentz  KAN      5     3
#     Marcus Mariota  WAS     46     3
#    Jacoby Brissett  NWE     45     8
#      Michael Penix  ATL     44     5
#    Lamar Jackson*+  BAL    430    17
#        Josh Allen*  BUF    379    17
#        Joe Burrow*  CIN    373    17
#    Baker Mayfield*  TAM    366    17
#    Jayden Daniels*  WAS    356    17
#        Jared Goff*  DET    323    17
#             Bo Nix  DEN    316    17
#
# Top 25 RB:
#                Player Team FantPt Games
#             Ray Davis  BUF     99    17
#           Jerome Ford  CLE     97    14
#         Austin Ekeler  WAS     97    12
#        Tyler Allgeier  ATL     93    17
#        Travis Etienne  JAX     91    15
#          Deuce Vaughn  DAL      9     7
#         Jaylen Warren  PIT     86    15
#        Ameer Abdullah  LVR     85    16
#          Justice Hill  BAL     85    15
#        Emanuel Wilson  GNB     85    17
#          Tyjae Spears  TEN     84    12
#        Antonio Gibson  NWE     80    17
#           Jeff Wilson  MIA      8     9
#     Raheem Blackshear  CAR      8    16
#        Isaac Guerendo  SFO     79    16
#             Cam Akers  2TM     79    17
#      Devin Singletary  NYG     76    15
#            Ty Johnson  BUF     74    17
#     Jaleel McLaughlin  DEN     73    16
# Clyde Edwards-Helaire  NOR      7     2
#             Eric Gray  NYG      7    17
#         Braelon Allen  NYJ     66    17
#           Gus Edwards  LAC     61    11
#       Roschon Johnson  CHI     61    14
#           Sean Tucker  TAM     60    17
#
# Top 25 WR:
#              Player Team FantPt Games
#      Jalen McMillan  TAM     98    13
# Michael Pittman Jr.  IND     97    16
#   Demarcus Robinson  LAR     93    17
#        Adam Thielen  CAR     92    10
#       Jaylen Waddle  MIA     92    15
#         Rome Odunze  CHI     91    17
#       Marvin Mims*+  DEN     91    17
#     DeAndre Hopkins  2TM     91    16
#   Wan'Dale Robinson  NYG     90    17
#            DJ Chark  LAC      9     7
#      Marquise Brown  KAN      9     2
#     Parris Campbell  PHI      9     5
#        Allen Lazard  NYJ     89    12
#           Tank Dell  HOU     89    14
#        Chris Godwin  TAM     88     7
#         Romeo Doubs  GNB     86    13
#      Andrei Iosivas  CIN     84    17
#        Keon Coleman  BUF     83    13
#   Calvin Austin III  PIT     83    17
#          Tre Tucker  LVR     82    17
#     Demario Douglas  NWE     82    17
#      Devin Duvernay  JAX      8    13
#           Zay Jones  ARI      8    11
#        Jalen Reagor  LAC      8     8
#     Devontez Walker  BAL      8     9
#
# Top 25 TE:
#            Player Team FantPt Games
#     Travis Kelce*  KAN     98    16
#   Harrison Bryant  LVR      9    13
# Brevyn Spann-Ford  DAL      9    17
#       Ben Sinnott  WAS      9    17
#    Chris Manhertz  NYG      9    17
#        Devin Culp  TAM      9     5
#       David Njoku  CLE     85    11
#        Kyle Pitts  ATL     84    17
#     Isaiah Likely  BAL     82    16
#        Cade Otton  TAM     82    14
#      Hunter Henry  NWE     79    16
#       Taysom Hill  NOR     79     8
#      Mike Gesicki  CIN     77    17
#     Juwan Johnson  NOR     73    17
#         Cole Kmet  CHI     73    17
#         Noah Gray  KAN     73    17
#     Foster Moreau  NOR     71    17
#     Tyler Conklin  NYJ     71    16
#      Luke Farrell  JAX      7    17
#      Hayden Hurst  LAC      7     9
#      E.J. Jenkins  PHI      7     8
#    Dalton Schultz  HOU     65    17
#     Austin Hooper  NWE     64    17
#    Dallas Goedert  PHI     62    10
# Chigoziem Okonkwo  TEN     62    17
#
# Top 25 DEF:
# Empty DataFrame
# Columns: [Player, Team, FantPt, Games]
# Index: []

# %%
# --------------------------------------------------------------------------------------------------------
# below code would be if I was cleaning the code from a df created directly from scraping the data off the site

# %%
def normalize_column_names(df):
    df.columns = (
        df.columns
        .str.lower()
        .str.replace(' ', '_')
        .str.replace(r'[^\w_]', '', regex=True)
    )

    rename_map = {
        'player': 'player',
        'tm': 'team',
        'fantasy_fantpt': 'fantasy_points',
        'fantasy_posrank': 'pos_rank',
        'fantasy_ovrank': 'ovr_rank',
        'rushing_yds': 'rush_yds',
        'rushing_td': 'rush_td',
        'receiving_yds': 'rec_yds',
        'receiving_td': 'rec_td',
        'passing_yds': 'pass_yds',
        'passing_td': 'pass_td',
        'passing_int': 'interceptions',
        'season': 'season'
    }

    df.rename(columns={k: v for k, v in rename_map.items() if k in df.columns}, inplace=True)
    return df

# %%
# If any tables had multi-level column headers, flatten them
# Flatten MultiIndex columns into single strings

df.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in df.columns]

# Check the first 10 column names to confirm
print("✅ Flattened Columns:\n", df.columns[:10])
# Out:
# ✅ Flattened Columns:
#  Index(['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0',
#        'Unnamed: 3_level_0', 'Unnamed: 4_level_0', 'Games', 'Games.1',
#        'Passing', 'Passing.1', 'Passing.2'],
#       dtype='object')

# %%
df = df.rename(columns={
    'Fantasy FantPt': 'FantPt',
    'Fumbles Fmb': 'Fumbles',
    'Games G': 'Games',
    'Unnamed: 0_level_0 Rk': 'Rk',
    'Unnamed: 1_level_0 Player': 'Player',
    'Unnamed: 2_level_0 Tm': 'Team',
    'Unnamed: 3_level_0 FantPos': 'Position',
    'Unnamed: 4_level_0 Age': 'Age',
    'Fantasy PosRank': 'Pos_Rank',
    'Fantasy OvRank': 'Ovr_Rank'
})
print(df.columns)
# Out:
# Index(['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0',
#        'Unnamed: 3_level_0', 'Unnamed: 4_level_0', 'Games', 'Games.1',
#        'Passing', 'Passing.1', 'Passing.2', 'Passing.3', 'Passing.4',
#        'Rushing', 'Rushing.1', 'Rushing.2', 'Rushing.3', 'Receiving',
#        'Receiving.1', 'Receiving.2', 'Receiving.3', 'Receiving.4', 'Fumbles',
#        'Fumbles.1', 'Scoring', 'Scoring.1', 'Scoring.2', 'Fantasy',
#        'Fantasy.1', 'Fantasy.2', 'Fantasy.3', 'Fantasy.4', 'Fantasy.5',
#        'Fantasy.6', 'Season'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0',
#        'Unnamed: 3_level_0', 'Unnamed: 4_level_0', 'Games', 'Games.1',
#        'Passing', 'Passing.1', 'Passing.2', 'Passing.3', 'Passing.4',
#        'Rushing', 'Rushing.1', 'Rushing.2', 'Rushing.3', 'Receiving',
#        'Receiving.1', 'Receiving.2', 'Receiving.3', 'Receiving.4', 'Fumbles',
#        'Fumbles.1', 'Scoring', 'Scoring.1', 'Scoring.2', 'Fantasy',
#        'Fantasy.1', 'Fantasy.2', 'Fantasy.3', 'Fantasy.4', 'Fantasy.5',
#        'Fantasy.6', 'Season'],
#       dtype='object')

# %%
print(fantasy_df[['Player', 'FantPt', 'Fumbles', 'Position', 'Age']].head())
# Out:
#            Player  FantPt  Fumbles Position Age
# 0   Todd Gurley*+     319        5       RB  23
# 1  Le'Veon Bell*+     257        3       RB  25
# 2    Kareem Hunt*     242        1       RB  22
# 3   Alvin Kamara*     239        1       RB  22
# 4   Melvin Gordon     230        1       RB  24

# %%
# Drop rows with missing or repeated headers
fantasy_df = fantasy_df[fantasy_df['Player'].notna()]
fantasy_df = fantasy_df[fantasy_df['Player'] != 'Player']

# Fill NaNs
fantasy_df['FantPt'] = fantasy_df['FantPt'].fillna(0)
fantasy_df['Fumbles'] = fantasy_df['Fumbles'].fillna(0)

# Cast numeric columns
fantasy_df['FantPt'] = pd.to_numeric(fantasy_df['FantPt'], errors='coerce')
fantasy_df['Fumbles'] = pd.to_numeric(fantasy_df['Fumbles'], errors='coerce')

# %%
print(fantasy_df[['Player']].value_counts().head())
# Out:
# Player
# Chris Moore       9
# Nelson Agholor    8
# Allen Robinson    8
# Johnny Mundt      8
# Gerald Everett    8
# Name: count, dtype: int64

# %%
season_dfs = {
    season: fantasy_df[fantasy_df['Season'] == season].reset_index(drop=True)
    for season in fantasy_df['Season'].unique()
}

# %%
season_dfs[2018]['Player'].value_counts().head()
# Out:
# Player
# Todd Gurley*+    1
# Kenjon Barner    1
# Corey Coleman    1
# Tyler Conklin    1
# Matt Lengel      1
# Name: count, dtype: int64
